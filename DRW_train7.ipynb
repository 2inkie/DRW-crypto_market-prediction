# %%
# %pip install optuna kneed
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting kneed
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from kneed) (1.15.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.3 MB/s eta 0:00:00
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 20.7 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, kneed, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 kneed-0.8.5 optuna-4.3.0

# %%
import gc, json, pickle
import optuna
import joblib
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from kneed import KneeLocator
from xgboost import XGBRegressor
from google.colab import drive
from joblib import Parallel, delayed
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.model_selection import TimeSeriesSplit
from collections import defaultdict
from scipy.stats import pearsonr, zscore
from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class DataLoader:
  def __init__(self, data_path, file_name):
    self.data_path = data_path
    self.file_name = file_name

  def load(self):
    df = pd.read_parquet(self.data_path + self.file_name)
    self.df = df.loc[:, ~((df == -np.inf).any() | (df == 0).all())]
    print('Data loaded')
    return self

  def train_split(self):
    label = self.df['label']
    qty_vol = self.df[['bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume']]
    X_ = self.df.drop(['label', 'bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume'], axis=1)
    return X_, qty_vol, label

  def test_split(self):
    qty_vol = self.df[['bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume']]
    X_ = self.df.drop(['bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume'], axis=1)
    return X_, qty_vol

  def load_features_json_list(self):
    with open(self.data_path + self.file_name, 'r') as f:
      return json.load(f)

# %%
class FeatureGenerator:
  def __init__(self, df, epsilon=1e-6):
    self.df = df
    self.epsilon = epsilon

  def develop_features_from_qty_volume(self):
    '''
      Function to develop features from bid_qty, ask_qty, buy_qty, sell_qty
      and volume columns.
    '''
    imbalance = (self.df['bid_qty'] - self.df['ask_qty']) / (self.df['bid_qty'] + self.df['ask_qty'] + self.epsilon)
    buy_sell_ratio = np.log1p(self.df['buy_qty'] / (self.df['sell_qty'] + self.epsilon))
    volume_z = zscore(self.df['volume'])

    return pd.DataFrame({
        'imbalance': imbalance,
        'buy_sell_ratio': buy_sell_ratio,
        'volume_z': volume_z
        }, index=self.df.index)

  def standardize_columns(self, columns):
    '''Function to standardize specific columns wihtin a df.'''
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(self.df[columns])
    df_scaled = pd.DataFrame(df_scaled, columns=columns, index=self.df.index)
    return pd.concat([df_scaled, self.df['label']], axis=1)

  def standardize_df(self):
    '''Function to standardize a whole df.'''
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(self.df)
    return pd.DataFrame(df_scaled, columns=self.df.columns, index=self.df.index)

# %%
class CorrelationAnalyzer:
  def __init__(self, feature, label):
    self.feature = feature
    self.label = label

  def _correlation(self, feature, label):
    '''
    Calcualte the Pearson correlation and p-value
    for a single feature and Y
    '''
    r, p = pearsonr(feature, label)
    return r, p

  def compute_correlations_in_window(self, window='2D'):
    '''
    Calcualte the Pearson correlation and p-value
    for each window between each feature and Y
    '''
    grouped_feature = self.feature.groupby(pd.Grouper(freq=window))
    grouped_label = self.label.groupby(pd.Grouper(freq=window))
    results = []
    for (period_start_feature, df_window_feature,
         _, df_window_label) in (
        zip(grouped_feature, grouped_label)):

      output = Parallel(n_jobs=-1)(
          delayed(self._correlation)(f, l) for f, l in (
              zip(df_window_feature, df_window_label)
              )
          )

      for feature, r, p in output:
        results.append({
            'period_start': period_start_feature,
            'feature': feature,
            'correlation': r,
            'p_value': p
            })

    return pd.DataFrame(results)

  def score_features(self, df_correlations, epsilon=1e-6):
    '''
    Score features based on their correlation with Y as a:
      base_score:
        correlation_mean / correlation_std

      adjusted_score:
        base_score * (1 / p_value_mean)
    '''
    summary = df_correlations.groupby('feature').agg({
        'correlation': ['mean', 'std'],
        'p_value': 'mean'
        })

    summary['base_score'] = (
        abs(summary[('correlation', 'mean')]) / (summary[('correlation', 'std')]
                                                 + epsilon)
    )

    summary['adjusted_score'] = (summary['base_score'] *
     (1 / summary[('p_value', 'mean')] + epsilon))

    return summary

  def number_of_features_to_select(self, summary, score='adjusted_score'):
    df_sorted = summary.sort_values(by=score, ascending=False).reset_index()
    df_sorted.rename(columns={"index": "feature"}, inplace=True)
    df_sorted["cumulative_score"] = df_sorted[score].cumsum()
    df_sorted["normalized_score"] = df_sorted["cumulative_score"] / df_sorted["cumulative_score"].iloc[-1]
    df_sorted["feature_index"] = np.arange(1, len(df_sorted) + 1)

    first_point = np.array([0, df_sorted["normalized_score"].iloc[0]])
    last_point = np.array([len(df_sorted) - 1, df_sorted["normalized_score"].iloc[-1]])
    line_vec = last_point - first_point
    line_vec_norm = line_vec / np.linalg.norm(line_vec)

    distances = []
    for i in range(len(df_sorted)):
        point = np.array([i, df_sorted["normalized_score"].iloc[i]])
        vec_from_first = point - first_point
        proj_len = np.dot(vec_from_first, line_vec_norm)
        proj_point = first_point + proj_len * line_vec_norm
        dist = np.linalg.norm(point - proj_point)
        distances.append(dist)

    elbow_index = int(np.argmax(distances))
    optimal_n_features = elbow_index + 1
    selected_features = df_sorted["feature"].iloc[:optimal_n_features].tolist()

    return optimal_n_features, selected_features, df_sorted

  def select_top_features(self, summary, top_k=55, score='adjusted_score'):
    sorted_summary = summary.sort_values(score, ascending=False)
    top_k_df = sorted_summary.head(top_k)
    return top_k_df.index.tolist()

# %%
class LagCreator:
  def __init__(self, lag_periods = 5):
    self.lag_periods = lag_periods

  def lag_features(self, X):

    lagged_columns = []
    for col in X.columns:
        for lag in range(1, self.lag_periods + 1):
          shifted = X[col].shift(lag)
          shifted.name = f"{col}_lag{lag}"
          lagged_columns.append(shifted)

    lagged = pd.concat(lagged_columns, axis=1)
    lagged = pd.concat([X, lagged], axis=1)
    return lagged.dropna()

  def match_index_lags(self, X_lagged, Y):
    '''Y is series with a single column'''
    y_lagged = Y.loc[X_lagged.index]

    return y_lagged

# %%
class CorrelationBatches:
  def __init__(self, df, lags, Y, freq):
    self.Y_column = Y
    self.df = df
    self.lags = lags
    self.freq = freq

  def _lag_column(self, column_df, feature_name, l):
    '''Create a lagged version of a given feature column.'''
    lagged_col = column_df.shift(1).dropna()
    lagged_col.name = f"{feature_name}_lag{l}"
    return lagged_col

  def _standardize_col(self, column_df):
    '''Standardize a feature column'''
    scaler = StandardScaler()
    scaled_col = scaler.fit_transform(column_df.values.reshape(-1, 1))
    scaled_col = pd.Series(scaled_col.flatten(), index=column_df.index, name=column_df.name)
    return scaled_col

  def _col_label_corr(self, period_start, column_df):
    '''Compute Pearson correlation between a feature column and the target column.'''
    y = self.Y_column.loc[column_df.index]
    column_df = self._standardize_col(column_df)
    corr, p = pearsonr(column_df, y)
    return column_df.name, period_start, corr, p

  def feature_correlation(self, feature):
    '''
    Compute correlations of a feature and its lagged versions with the target column.
    Each call standardizes the values, then calculates the Pearson correlation
    and p-value accross windows of 3 days.
    Then it creates lagged versions of the feature and repeats the process.
    Returns:
      list: A list of three lists containing:
        [0] Feature names (including lags),
        [1] Correlation coefficients,
        [2] Corresponding p-values.

    '''
    feature_correlations = []

    feature_df = self.df[feature]
    grouped = feature_df.groupby(pd.Grouper(freq=self.freq))
    output = Parallel(n_jobs=-1)(
        delayed(self._col_label_corr)(period_start, df_g) for period_start, df_g in grouped
        )

    feature_correlations.append(output)

    ft_name = feature_df.name

    for lag in range(1, self.lags + 1):
      feature_df = self._lag_column(feature_df, ft_name, lag)
      grouped = feature_df.groupby(pd.Grouper(freq=self.freq))
      output = Parallel(n_jobs=-1)(
          delayed(self._col_label_corr)(period_start, df_g) for period_start, df_g in grouped
          )

      feature_correlations.append(output)

    return feature_correlations

# %%
class FeatureLagSelector:
    def __init__(self, feature_list):
        '''
        Initialize the selector with a list of desired features.
        Features can be raw (e.g., 'X264') or lagged (e.g., 'X264_lag2')
        '''
        self.feature_list = feature_list
        self.selected_features = {}

    def _parse_feature(self, feature_name):

        '''Parse feature name into base column and lag value (if present).'''

        if '_lag' in feature_name:
            base, lag = feature_name.split('_lag')
            return base, int(lag)
        return feature_name, None

    def _transform(self, df):
        '''Build a new DataFrame with the selected and lagged features.'''

        self.selected_features.clear()
        for feature in self.feature_list:
            base, lag = self._parse_feature(feature)
            if base not in df.columns:
                print(f"Base column '{base}' not found in DataFrame")
                continue
            if lag is None:
                self.selected_features[feature] = df[base]
            else:
                self.selected_features[feature] = df[base].shift(lag)

        return pd.DataFrame(self.selected_features)

    def fit_transform(self, df):
        return self._transform(df)

# %%
class PCAProcessor:
  def __init__(self, X_selected, groups, path_to_save_results, file_name):
    self.X_selected = X_selected
    self.groups = groups
    self.path_to_save_results = path_to_save_results
    self.file_name = file_name

  def _pca_transform(self, g, n_components):
    pca = PCA(n_components=n_components)
    g_pca = pca.fit_transform(self.X_selected[g])
    return g_pca

  def _pca_explained_variance(self, g):
    pca = PCA()
    pca.fit(self.X_selected[g])
    return pca.explained_variance_ratio_

  def _penalized_score(self, g, alpha = 0.005):
    scores = []
    explained_variance = self._pca_explained_variance(g)

    for k in range(1, len(explained_variance) + 1):
      score = explained_variance[:k].sum() - alpha * k
      scores.append(score)

    return np.argmax(scores) + 1, g

  def _best_number_of_components(self, alpha = 0.005):
    '''Finds the best number of components for each group utilizing the penalized score'''
    results = Parallel(n_jobs=-1)(
        delayed(self._penalized_score)(g, alpha) for g in self.groups
    )

    self.n_components = []
    self.groups_features = []

    for n, g in results:
      self.n_components.append(n)
      self.groups_features.append(g)
    return self.n_components, self.groups_features

  def transform_data(self, penalizing_term_alpha = 0.005):
    '''A function that combines all the previous methods in order to output a
    df that contains all the pca components
    '''
    self.n_components, self.groups_features = self._best_number_of_components(penalizing_term_alpha)

    list_with_all_pca = []
    for idx, (g, n) in enumerate(zip(self.groups_features, self.n_components), start=1):
      g_pca = self._pca_transform(g, n)

      col_names = [f"G{idx}P{j+1}" for j in range(n)]
      df_pca_group = pd.DataFrame(g_pca, columns=col_names, index=self.X_selected.index)

      list_with_all_pca.append(df_pca_group)

    # Save the data to JSON
    self.n_components = [int(x) for x in self.n_components]
    best_PCA = [self.n_components, self.groups_features]
    with open(self.path_to_save_results + self.file_name, "w") as f:
        json.dump(best_PCA, f, indent=2)

    return pd.concat(list_with_all_pca, axis=1)

# %%
class ClusterAnalyzer:
  def __init__(self, X_selected):
    self.X_selected = X_selected

  def _correlation_matrix(self):
    '''Function to calculate correlation matrix'''
    corr_matrix = self.X_selected.corr().abs()
    return corr_matrix

  def _distance_matrix(self):
    '''Returns square matrix'''
    return (1 - self._correlation_matrix()).values

  def _hierarchical_clustering(self, method='average'):
    distance_matrix = self._distance_matrix()
    condensed_dist = squareform(distance_matrix, checks=True)
    Z = linkage(condensed_dist, method=method)
    return Z

  def _silhouette_score_cluster(self, labels, distance_matrix, metric='precomputed'):
    score = silhouette_score(distance_matrix, labels, metric=metric)
    return score

  def optimal_number_of_clusters(self, max_k = 15, min_k=2):
    '''
    max_k - maaximum number of clusters to create
    min_k - minimum number of clusters to create
    '''
    Z = self._hierarchical_clustering()
    distance_matrix = self._distance_matrix()

    best_score = -1
    self.best_k = None
    self.results = {}
    for k in range(min_k, max_k):
      labels = fcluster(Z, k, criterion='maxclust')
      score = self._silhouette_score_cluster(labels, distance_matrix)
      print(f"Number of clusters: {k}, Silhouette score: {score}")
      if score > best_score:
        self.best_k, best_score = k, score

      self.results[k] = [score, labels]

    return self.best_k, best_score, self.results

  def groups_split(self):
    # Create groups of feature names where each group is a cluster
    best_clusters = self.results[self.best_k][1]
    labels_columns = self.X_selected.columns.tolist()

    n_clusters = max(best_clusters)

    clustered_features = [[] for _ in range(n_clusters)]

    for c, e in zip(best_clusters, labels_columns):
        clustered_features[c - 1].append(e)

    return clustered_features

  def save_results(self, dataPath, fileName):
    '''Save clustering results using simple string concatenation.'''
    full_path = dataPath + fileName

    with open(full_path, 'wb') as f:
        pickle.dump({
            'best_k': self.best_k,
            'results': self.results,
            'columns': self.X_selected.columns.tolist()
        }, f)

    print(f"Clustering results saved to {full_path}")


  # def cluster_features(self, X_selected, n_clusters = 7, criterion = 'maxclust'):
  #   Z = self._hierarchical_clustering(X_selected)
  #   cluster_ids = fcluster(Z, n_clusters, criterion=criterion)
  #   feature_groups = defaultdict(list)
  #   for feature, cluster_id in zip(X_selected.columns, cluster_ids):
  #     feature_groups[cluster_id].append(feature)

  #   groups = list(feature_groups.values())
  #   return groups, Z

  def visualize_clusters(self):
    Z = self._hierarchical_clustering()
    plt.figure(figsize=(12, 6))
    dendrogram(Z, labels=self.X_selected.columns.tolist(), leaf_rotation=90)
    plt.title("Dendrogram of Feature Clustering")
    plt.tight_layout()
    plt.show()

# %%
# Features
# Group 1 - X1, X2 ....
# Group 2 - _qty, vol

# %%
# Filepaths
dataPathLoad = '/content/drive/MyDrive/Colab Notebooks/DRW/data/'
dataPathSave = '/content/drive/MyDrive/Colab Notebooks/DRW/data/v7'
fileNameTrain = 'train.parquet'

# %%
# Load train data and remove -inf columns and columns full of 0
loader = DataLoader(dataPathLoad, fileNameTrain)
features_group1, features_group2, label = loader.load().train_split()
del loader
gc.collect()
# Out:
# Data loaded
# 17

# %%
# Calculate correlations in batches
results = {}
columns = features_group1.columns
count = 1
for col in columns:
  batchesCorrelation = CorrelationBatches(features_group1, 3, label, '1D')
  out = batchesCorrelation.feature_correlation(col)

  results[col] = out
  print(f'Processed {count} out of {len(columns)}')
  count += 1
# Out:
# Processed 1 out of 863
# Processed 2 out of 863
# Processed 3 out of 863
# Processed 4 out of 863
# Processed 5 out of 863
# Processed 6 out of 863
# Processed 7 out of 863
# Processed 8 out of 863
# Processed 9 out of 863
# Processed 10 out of 863
# Processed 11 out of 863
# Processed 12 out of 863
# Processed 13 out of 863
# Processed 14 out of 863
# Processed 15 out of 863
# Processed 16 out of 863
# Processed 17 out of 863
# Processed 18 out of 863
# Processed 19 out of 863
# Processed 20 out of 863
# Processed 21 out of 863
# Processed 22 out of 863
# Processed 23 out of 863
# Processed 24 out of 863
# Processed 25 out of 863
# Processed 26 out of 863
# Processed 27 out of 863
# Processed 28 out of 863
# Processed 29 out of 863
# Processed 30 out of 863
# Processed 31 out of 863
# Processed 32 out of 863
# Processed 33 out of 863
# Processed 34 out of 863
# Processed 35 out of 863
# Processed 36 out of 863
# Processed 37 out of 863
# Processed 38 out of 863
# Processed 39 out of 863
# Processed 40 out of 863
# Processed 41 out of 863
# Processed 42 out of 863
# Processed 43 out of 863
# Processed 44 out of 863
# Processed 45 out of 863
# Processed 46 out of 863
# Processed 47 out of 863
# Processed 48 out of 863
# Processed 49 out of 863
# Processed 50 out of 863
# Processed 51 out of 863
# Processed 52 out of 863
# Processed 53 out of 863
# Processed 54 out of 863
# Processed 55 out of 863
# Processed 56 out of 863
# Processed 57 out of 863
# Processed 58 out of 863
# Processed 59 out of 863
# Processed 60 out of 863
# Processed 61 out of 863
# Processed 62 out of 863
# Processed 63 out of 863
# Processed 64 out of 863
# Processed 65 out of 863
# Processed 66 out of 863
# Processed 67 out of 863
# Processed 68 out of 863
# Processed 69 out of 863
# Processed 70 out of 863
# Processed 71 out of 863
# Processed 72 out of 863
# Processed 73 out of 863
# Processed 74 out of 863
# Processed 75 out of 863
# Processed 76 out of 863
# Processed 77 out of 863
# Processed 78 out of 863
# Processed 79 out of 863
# Processed 80 out of 863
# Processed 81 out of 863
# Processed 82 out of 863
# Processed 83 out of 863
# Processed 84 out of 863
# Processed 85 out of 863
# Processed 86 out of 863
# Processed 87 out of 863
# Processed 88 out of 863
# Processed 89 out of 863
# Processed 90 out of 863
# Processed 91 out of 863
# Processed 92 out of 863
# Processed 93 out of 863
# Processed 94 out of 863
# Processed 95 out of 863
# Processed 96 out of 863
# Processed 97 out of 863
# Processed 98 out of 863
# Processed 99 out of 863
# Processed 100 out of 863
# Processed 101 out of 863
# Processed 102 out of 863
# Processed 103 out of 863
# Processed 104 out of 863
# Processed 105 out of 863
# Processed 106 out of 863
# Processed 107 out of 863
# Processed 108 out of 863
# Processed 109 out of 863
# Processed 110 out of 863
# Processed 111 out of 863
# Processed 112 out of 863
# Processed 113 out of 863
# Processed 114 out of 863
# Processed 115 out of 863
# Processed 116 out of 863
# Processed 117 out of 863
# Processed 118 out of 863
# Processed 119 out of 863
# Processed 120 out of 863
# Processed 121 out of 863
# Processed 122 out of 863
# Processed 123 out of 863
# Processed 124 out of 863
# Processed 125 out of 863
# Processed 126 out of 863
# Processed 127 out of 863
# Processed 128 out of 863
# Processed 129 out of 863
# Processed 130 out of 863
# Processed 131 out of 863
# Processed 132 out of 863
# Processed 133 out of 863
# Processed 134 out of 863
# Processed 135 out of 863
# Processed 136 out of 863
# Processed 137 out of 863
# Processed 138 out of 863
# Processed 139 out of 863
# Processed 140 out of 863
# Processed 141 out of 863
# Processed 142 out of 863
# Processed 143 out of 863
# Processed 144 out of 863
# Processed 145 out of 863
# Processed 146 out of 863
# Processed 147 out of 863
# Processed 148 out of 863
# Processed 149 out of 863
# Processed 150 out of 863
# Processed 151 out of 863
# Processed 152 out of 863
# Processed 153 out of 863
# Processed 154 out of 863
# Processed 155 out of 863
# Processed 156 out of 863
# Processed 157 out of 863
# Processed 158 out of 863
# Processed 159 out of 863
# Processed 160 out of 863
# Processed 161 out of 863
# Processed 162 out of 863
# Processed 163 out of 863
# Processed 164 out of 863
# Processed 165 out of 863
# Processed 166 out of 863
# Processed 167 out of 863
# Processed 168 out of 863
# Processed 169 out of 863
# Processed 170 out of 863
# Processed 171 out of 863
# Processed 172 out of 863
# Processed 173 out of 863
# Processed 174 out of 863
# Processed 175 out of 863
# Processed 176 out of 863
# Processed 177 out of 863
# Processed 178 out of 863
# Processed 179 out of 863
# Processed 180 out of 863
# Processed 181 out of 863
# Processed 182 out of 863
# Processed 183 out of 863
# Processed 184 out of 863
# Processed 185 out of 863
# Processed 186 out of 863
# Processed 187 out of 863
# Processed 188 out of 863
# Processed 189 out of 863
# Processed 190 out of 863
# Processed 191 out of 863
# Processed 192 out of 863
# Processed 193 out of 863
# Processed 194 out of 863
# Processed 195 out of 863
# Processed 196 out of 863
# Processed 197 out of 863
# Processed 198 out of 863
# Processed 199 out of 863
# Processed 200 out of 863
# Processed 201 out of 863
# Processed 202 out of 863
# Processed 203 out of 863
# Processed 204 out of 863
# Processed 205 out of 863
# Processed 206 out of 863
# Processed 207 out of 863
# Processed 208 out of 863
# Processed 209 out of 863
# Processed 210 out of 863
# Processed 211 out of 863
# Processed 212 out of 863
# Processed 213 out of 863
# Processed 214 out of 863
# Processed 215 out of 863
# Processed 216 out of 863
# Processed 217 out of 863
# Processed 218 out of 863
# Processed 219 out of 863
# Processed 220 out of 863
# Processed 221 out of 863
# Processed 222 out of 863
# Processed 223 out of 863
# Processed 224 out of 863
# Processed 225 out of 863
# Processed 226 out of 863
# Processed 227 out of 863
# Processed 228 out of 863
# Processed 229 out of 863
# Processed 230 out of 863
# Processed 231 out of 863
# Processed 232 out of 863
# Processed 233 out of 863
# Processed 234 out of 863
# Processed 235 out of 863
# Processed 236 out of 863
# Processed 237 out of 863
# Processed 238 out of 863
# Processed 239 out of 863
# Processed 240 out of 863
# Processed 241 out of 863
# Processed 242 out of 863
# Processed 243 out of 863
# Processed 244 out of 863
# Processed 245 out of 863
# Processed 246 out of 863
# Processed 247 out of 863
# Processed 248 out of 863
# Processed 249 out of 863
# Processed 250 out of 863
# Processed 251 out of 863
# Processed 252 out of 863
# Processed 253 out of 863
# Processed 254 out of 863
# Processed 255 out of 863
# Processed 256 out of 863
# Processed 257 out of 863
# Processed 258 out of 863
# Processed 259 out of 863
# Processed 260 out of 863
# Processed 261 out of 863
# Processed 262 out of 863
# Processed 263 out of 863
# Processed 264 out of 863
# Processed 265 out of 863
# Processed 266 out of 863
# Processed 267 out of 863
# Processed 268 out of 863
# Processed 269 out of 863
# Processed 270 out of 863
# Processed 271 out of 863
# Processed 272 out of 863
# Processed 273 out of 863
# Processed 274 out of 863
# Processed 275 out of 863
# Processed 276 out of 863
# Processed 277 out of 863
# Processed 278 out of 863
# Processed 279 out of 863
# Processed 280 out of 863
# Processed 281 out of 863
# Processed 282 out of 863
# Processed 283 out of 863
# Processed 284 out of 863
# Processed 285 out of 863
# Processed 286 out of 863
# Processed 287 out of 863
# Processed 288 out of 863
# Processed 289 out of 863
# Processed 290 out of 863
# Processed 291 out of 863
# Processed 292 out of 863
# Processed 293 out of 863
# Processed 294 out of 863
# Processed 295 out of 863
# Processed 296 out of 863
# Processed 297 out of 863
# Processed 298 out of 863
# Processed 299 out of 863
# Processed 300 out of 863
# Processed 301 out of 863
# Processed 302 out of 863
# Processed 303 out of 863
# Processed 304 out of 863
# Processed 305 out of 863
# Processed 306 out of 863
# Processed 307 out of 863
# Processed 308 out of 863
# Processed 309 out of 863
# Processed 310 out of 863
# Processed 311 out of 863
# Processed 312 out of 863
# Processed 313 out of 863
# Processed 314 out of 863
# Processed 315 out of 863
# Processed 316 out of 863
# Processed 317 out of 863
# Processed 318 out of 863
# Processed 319 out of 863
# Processed 320 out of 863
# Processed 321 out of 863
# Processed 322 out of 863
# Processed 323 out of 863
# Processed 324 out of 863
# Processed 325 out of 863
# Processed 326 out of 863
# Processed 327 out of 863
# Processed 328 out of 863
# Processed 329 out of 863
# Processed 330 out of 863
# Processed 331 out of 863
# Processed 332 out of 863
# Processed 333 out of 863
# Processed 334 out of 863
# Processed 335 out of 863
# Processed 336 out of 863
# Processed 337 out of 863
# Processed 338 out of 863
# Processed 339 out of 863
# Processed 340 out of 863
# Processed 341 out of 863
# Processed 342 out of 863
# Processed 343 out of 863
# Processed 344 out of 863
# Processed 345 out of 863
# Processed 346 out of 863
# Processed 347 out of 863
# Processed 348 out of 863
# Processed 349 out of 863
# Processed 350 out of 863
# Processed 351 out of 863
# Processed 352 out of 863
# Processed 353 out of 863
# Processed 354 out of 863
# Processed 355 out of 863
# Processed 356 out of 863
# Processed 357 out of 863
# Processed 358 out of 863
# Processed 359 out of 863
# Processed 360 out of 863
# Processed 361 out of 863
# Processed 362 out of 863
# Processed 363 out of 863
# Processed 364 out of 863
# Processed 365 out of 863
# Processed 366 out of 863
# Processed 367 out of 863
# Processed 368 out of 863
# Processed 369 out of 863
# Processed 370 out of 863
# Processed 371 out of 863
# Processed 372 out of 863
# Processed 373 out of 863
# Processed 374 out of 863
# Processed 375 out of 863
# Processed 376 out of 863
# Processed 377 out of 863
# Processed 378 out of 863
# Processed 379 out of 863
# Processed 380 out of 863
# Processed 381 out of 863
# Processed 382 out of 863
# Processed 383 out of 863
# Processed 384 out of 863
# Processed 385 out of 863
# Processed 386 out of 863
# Processed 387 out of 863
# Processed 388 out of 863
# Processed 389 out of 863
# Processed 390 out of 863
# Processed 391 out of 863
# Processed 392 out of 863
# Processed 393 out of 863
# Processed 394 out of 863
# Processed 395 out of 863
# Processed 396 out of 863
# Processed 397 out of 863
# Processed 398 out of 863
# Processed 399 out of 863
# Processed 400 out of 863
# Processed 401 out of 863
# Processed 402 out of 863
# Processed 403 out of 863
# Processed 404 out of 863
# Processed 405 out of 863
# Processed 406 out of 863
# Processed 407 out of 863
# Processed 408 out of 863
# Processed 409 out of 863
# Processed 410 out of 863
# Processed 411 out of 863
# Processed 412 out of 863
# Processed 413 out of 863
# Processed 414 out of 863
# Processed 415 out of 863
# Processed 416 out of 863
# Processed 417 out of 863
# Processed 418 out of 863
# Processed 419 out of 863
# Processed 420 out of 863
# Processed 421 out of 863
# Processed 422 out of 863
# Processed 423 out of 863
# Processed 424 out of 863
# Processed 425 out of 863
# Processed 426 out of 863
# Processed 427 out of 863
# Processed 428 out of 863
# Processed 429 out of 863
# Processed 430 out of 863
# Processed 431 out of 863
# Processed 432 out of 863
# Processed 433 out of 863
# Processed 434 out of 863
# Processed 435 out of 863
# Processed 436 out of 863
# Processed 437 out of 863
# Processed 438 out of 863
# Processed 439 out of 863
# Processed 440 out of 863
# Processed 441 out of 863
# Processed 442 out of 863
# Processed 443 out of 863
# Processed 444 out of 863
# Processed 445 out of 863
# Processed 446 out of 863
# Processed 447 out of 863
# Processed 448 out of 863
# Processed 449 out of 863
# Processed 450 out of 863
# Processed 451 out of 863
# Processed 452 out of 863
# Processed 453 out of 863
# Processed 454 out of 863
# Processed 455 out of 863
# Processed 456 out of 863
# Processed 457 out of 863
# Processed 458 out of 863
# Processed 459 out of 863
# Processed 460 out of 863
# Processed 461 out of 863
# Processed 462 out of 863
# Processed 463 out of 863
# Processed 464 out of 863
# Processed 465 out of 863
# Processed 466 out of 863
# Processed 467 out of 863
# Processed 468 out of 863
# Processed 469 out of 863
# Processed 470 out of 863
# Processed 471 out of 863
# Processed 472 out of 863
# Processed 473 out of 863
# Processed 474 out of 863
# Processed 475 out of 863
# Processed 476 out of 863
# Processed 477 out of 863
# Processed 478 out of 863
# Processed 479 out of 863
# Processed 480 out of 863
# Processed 481 out of 863
# Processed 482 out of 863
# Processed 483 out of 863
# Processed 484 out of 863
# Processed 485 out of 863
# Processed 486 out of 863
# Processed 487 out of 863
# Processed 488 out of 863
# Processed 489 out of 863
# Processed 490 out of 863
# Processed 491 out of 863
# Processed 492 out of 863
# Processed 493 out of 863
# Processed 494 out of 863
# Processed 495 out of 863
# Processed 496 out of 863
# Processed 497 out of 863
# Processed 498 out of 863
# Processed 499 out of 863
# Processed 500 out of 863
# Processed 501 out of 863
# Processed 502 out of 863
# Processed 503 out of 863
# Processed 504 out of 863
# Processed 505 out of 863
# Processed 506 out of 863
# Processed 507 out of 863
# Processed 508 out of 863
# Processed 509 out of 863
# Processed 510 out of 863
# Processed 511 out of 863
# Processed 512 out of 863
# Processed 513 out of 863
# Processed 514 out of 863
# Processed 515 out of 863
# Processed 516 out of 863
# Processed 517 out of 863
# Processed 518 out of 863
# Processed 519 out of 863
# Processed 520 out of 863
# Processed 521 out of 863
# Processed 522 out of 863
# Processed 523 out of 863
# Processed 524 out of 863
# Processed 525 out of 863
# Processed 526 out of 863
# Processed 527 out of 863
# Processed 528 out of 863
# Processed 529 out of 863
# Processed 530 out of 863
# Processed 531 out of 863
# Processed 532 out of 863
# Processed 533 out of 863
# Processed 534 out of 863
# Processed 535 out of 863
# Processed 536 out of 863
# Processed 537 out of 863
# Processed 538 out of 863
# Processed 539 out of 863
# Processed 540 out of 863
# Processed 541 out of 863
# Processed 542 out of 863
# Processed 543 out of 863
# Processed 544 out of 863
# Processed 545 out of 863
# Processed 546 out of 863
# Processed 547 out of 863
# Processed 548 out of 863
# Processed 549 out of 863
# Processed 550 out of 863
# Processed 551 out of 863
# Processed 552 out of 863
# Processed 553 out of 863
# Processed 554 out of 863
# Processed 555 out of 863
# Processed 556 out of 863
# Processed 557 out of 863
# Processed 558 out of 863
# Processed 559 out of 863
# Processed 560 out of 863
# Processed 561 out of 863
# Processed 562 out of 863
# Processed 563 out of 863
# Processed 564 out of 863
# Processed 565 out of 863
# Processed 566 out of 863
# Processed 567 out of 863
# Processed 568 out of 863
# Processed 569 out of 863
# Processed 570 out of 863
# Processed 571 out of 863
# Processed 572 out of 863
# Processed 573 out of 863
# Processed 574 out of 863
# Processed 575 out of 863
# Processed 576 out of 863
# Processed 577 out of 863
# Processed 578 out of 863
# Processed 579 out of 863
# Processed 580 out of 863
# Processed 581 out of 863
# Processed 582 out of 863
# Processed 583 out of 863
# Processed 584 out of 863
# Processed 585 out of 863
# Processed 586 out of 863
# Processed 587 out of 863
# Processed 588 out of 863
# Processed 589 out of 863
# Processed 590 out of 863
# Processed 591 out of 863
# Processed 592 out of 863
# Processed 593 out of 863
# Processed 594 out of 863
# Processed 595 out of 863
# Processed 596 out of 863
# Processed 597 out of 863
# Processed 598 out of 863
# Processed 599 out of 863
# Processed 600 out of 863
# Processed 601 out of 863
# Processed 602 out of 863
# Processed 603 out of 863
# Processed 604 out of 863
# Processed 605 out of 863
# Processed 606 out of 863
# Processed 607 out of 863
# Processed 608 out of 863
# Processed 609 out of 863
# Processed 610 out of 863
# Processed 611 out of 863
# Processed 612 out of 863
# Processed 613 out of 863
# Processed 614 out of 863
# Processed 615 out of 863
# Processed 616 out of 863
# Processed 617 out of 863
# Processed 618 out of 863
# Processed 619 out of 863
# Processed 620 out of 863
# Processed 621 out of 863
# Processed 622 out of 863
# Processed 623 out of 863
# Processed 624 out of 863
# Processed 625 out of 863
# Processed 626 out of 863
# Processed 627 out of 863
# Processed 628 out of 863
# Processed 629 out of 863
# Processed 630 out of 863
# Processed 631 out of 863
# Processed 632 out of 863
# Processed 633 out of 863
# Processed 634 out of 863
# Processed 635 out of 863
# Processed 636 out of 863
# Processed 637 out of 863
# Processed 638 out of 863
# Processed 639 out of 863
# Processed 640 out of 863
# Processed 641 out of 863
# Processed 642 out of 863
# Processed 643 out of 863
# Processed 644 out of 863
# Processed 645 out of 863
# Processed 646 out of 863
# Processed 647 out of 863
# Processed 648 out of 863
# Processed 649 out of 863
# Processed 650 out of 863
# Processed 651 out of 863
# Processed 652 out of 863
# Processed 653 out of 863
# Processed 654 out of 863
# Processed 655 out of 863
# Processed 656 out of 863
# Processed 657 out of 863
# Processed 658 out of 863
# Processed 659 out of 863
# Processed 660 out of 863
# Processed 661 out of 863
# Processed 662 out of 863
# Processed 663 out of 863
# Processed 664 out of 863
# Processed 665 out of 863
# Processed 666 out of 863
# Processed 667 out of 863
# Processed 668 out of 863
# Processed 669 out of 863
# Processed 670 out of 863
# Processed 671 out of 863
# Processed 672 out of 863
# Processed 673 out of 863
# Processed 674 out of 863
# Processed 675 out of 863
# Processed 676 out of 863
# Processed 677 out of 863
# Processed 678 out of 863
# Processed 679 out of 863
# Processed 680 out of 863
# Processed 681 out of 863
# Processed 682 out of 863
# Processed 683 out of 863
# Processed 684 out of 863
# Processed 685 out of 863
# Processed 686 out of 863
# Processed 687 out of 863
# Processed 688 out of 863
# Processed 689 out of 863
# Processed 690 out of 863
# Processed 691 out of 863
# Processed 692 out of 863
# Processed 693 out of 863
# Processed 694 out of 863
# Processed 695 out of 863
# Processed 696 out of 863
# Processed 697 out of 863
# Processed 698 out of 863
# Processed 699 out of 863
# Processed 700 out of 863
# Processed 701 out of 863
# Processed 702 out of 863
# Processed 703 out of 863
# Processed 704 out of 863
# Processed 705 out of 863
# Processed 706 out of 863
# Processed 707 out of 863
# Processed 708 out of 863
# Processed 709 out of 863
# Processed 710 out of 863
# Processed 711 out of 863
# Processed 712 out of 863
# Processed 713 out of 863
# Processed 714 out of 863
# Processed 715 out of 863
# Processed 716 out of 863
# Processed 717 out of 863
# Processed 718 out of 863
# Processed 719 out of 863
# Processed 720 out of 863
# Processed 721 out of 863
# Processed 722 out of 863
# Processed 723 out of 863
# Processed 724 out of 863
# Processed 725 out of 863
# Processed 726 out of 863
# Processed 727 out of 863
# Processed 728 out of 863
# Processed 729 out of 863
# Processed 730 out of 863
# Processed 731 out of 863
# Processed 732 out of 863
# Processed 733 out of 863
# Processed 734 out of 863
# Processed 735 out of 863
# Processed 736 out of 863
# Processed 737 out of 863
# Processed 738 out of 863
# Processed 739 out of 863
# Processed 740 out of 863
# Processed 741 out of 863
# Processed 742 out of 863
# Processed 743 out of 863
# Processed 744 out of 863
# Processed 745 out of 863
# Processed 746 out of 863
# Processed 747 out of 863
# Processed 748 out of 863
# Processed 749 out of 863
# Processed 750 out of 863
# Processed 751 out of 863
# Processed 752 out of 863
# Processed 753 out of 863
# Processed 754 out of 863
# Processed 755 out of 863
# Processed 756 out of 863
# Processed 757 out of 863
# Processed 758 out of 863
# Processed 759 out of 863
# Processed 760 out of 863
# Processed 761 out of 863
# Processed 762 out of 863
# Processed 763 out of 863
# Processed 764 out of 863
# Processed 765 out of 863
# Processed 766 out of 863
# Processed 767 out of 863
# Processed 768 out of 863
# Processed 769 out of 863
# Processed 770 out of 863
# Processed 771 out of 863
# Processed 772 out of 863
# Processed 773 out of 863
# Processed 774 out of 863
# Processed 775 out of 863
# Processed 776 out of 863
# Processed 777 out of 863
# Processed 778 out of 863
# Processed 779 out of 863
# Processed 780 out of 863
# Processed 781 out of 863
# Processed 782 out of 863
# Processed 783 out of 863
# Processed 784 out of 863
# Processed 785 out of 863
# Processed 786 out of 863
# Processed 787 out of 863
# Processed 788 out of 863
# Processed 789 out of 863
# Processed 790 out of 863
# Processed 791 out of 863
# Processed 792 out of 863
# Processed 793 out of 863
# Processed 794 out of 863
# Processed 795 out of 863
# Processed 796 out of 863
# Processed 797 out of 863
# Processed 798 out of 863
# Processed 799 out of 863
# Processed 800 out of 863
# Processed 801 out of 863
# Processed 802 out of 863
# Processed 803 out of 863
# Processed 804 out of 863
# Processed 805 out of 863
# Processed 806 out of 863
# Processed 807 out of 863
# Processed 808 out of 863
# Processed 809 out of 863
# Processed 810 out of 863
# Processed 811 out of 863
# Processed 812 out of 863
# Processed 813 out of 863
# Processed 814 out of 863
# Processed 815 out of 863
# Processed 816 out of 863
# Processed 817 out of 863
# Processed 818 out of 863
# Processed 819 out of 863
# Processed 820 out of 863
# Processed 821 out of 863
# Processed 822 out of 863
# Processed 823 out of 863
# Processed 824 out of 863
# Processed 825 out of 863
# Processed 826 out of 863
# Processed 827 out of 863
# Processed 828 out of 863
# Processed 829 out of 863
# Processed 830 out of 863
# Processed 831 out of 863
# Processed 832 out of 863
# Processed 833 out of 863
# Processed 834 out of 863
# Processed 835 out of 863
# Processed 836 out of 863
# Processed 837 out of 863
# Processed 838 out of 863
# Processed 839 out of 863
# Processed 840 out of 863
# Processed 841 out of 863
# Processed 842 out of 863
# Processed 843 out of 863
# Processed 844 out of 863
# Processed 845 out of 863
# Processed 846 out of 863
# Processed 847 out of 863
# Processed 848 out of 863
# Processed 849 out of 863
# Processed 850 out of 863
# Processed 851 out of 863
# Processed 852 out of 863
# Processed 853 out of 863
# Processed 854 out of 863
# Processed 855 out of 863
# Processed 856 out of 863
# Processed 857 out of 863
# Processed 858 out of 863
# Processed 859 out of 863
# Processed 860 out of 863
# Processed 861 out of 863
# Processed 862 out of 863
# Processed 863 out of 863

# %%
# Build pandas df from the results
dict_results = {
    'feature': [],
    'period_start': [],
    'correlation': [],
    'p_value': []
}
for key in results:
  for i in range(4):
    for out in results[key][i]:
      dict_results['feature'].append(out[0])
      dict_results['period_start'].append(out[1])
      dict_results['correlation'].append(out[2])
      dict_results['p_value'].append(out[3])

correlation_results_df = pd.DataFrame(dict_results)

# Save to csv
correlation_results_df.to_csv(dataPathSave + 'correlation_results_7.csv', index=False)

# %%
# Develop scores for each feature as:
  # base_score:
  #   correlation_mean / correlation_std

  # adjusted_score:
  #   base_score * (1 / p_value_mean)
correlation_analyzer = CorrelationAnalyzer(None, None)
summary = correlation_analyzer.score_features(correlation_results_df)

# %%
summary_sorted = summary.sort_values(by='adjusted_score', ascending=False)

# %%
# 480
selected_features = list(summary_sorted.head(480).index)

# %%
# Build features from the list of selected features
featureLagBuilder = FeatureLagSelector(selected_features)
X_selected = featureLagBuilder.fit_transform(features_group1)

# %%
# Delete not needed variables
del features_group1
gc.collect()
# Out:
# 318

# %%
# Standardize X
X_selected = FeatureGenerator(X_selected).standardize_df()

# %%
# Cluster features
cluster_analyzer = ClusterAnalyzer(X_selected)
best_k, best_score, results = cluster_analyzer.optimal_number_of_clusters(20)

# Save results
cluster_analyzer.save_results(dataPathSave, 'cluster_results7.pkl')
